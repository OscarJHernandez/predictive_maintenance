# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

x = np.linspace(0,2*np.pi,100)
y = np.sin(x) + np.random.random(100) * 0.2
yhat = savgol_filter(y, 61, 3) # window size 51, polynomial order 3

plt.plot(x,y)
plt.plot(x,yhat, color='red')
plt.show()

print(yhat)
# Out:
# [ 0.01658717  0.10730962  0.19353365  0.27531424  0.35270641  0.42576514
#   0.49454545  0.55910233  0.61949077  0.6757658   0.72798239  0.77619556
#   0.8204603   0.86083162  0.89736451  0.93011398  0.95913502  0.98448264
#   1.00621183  1.0243776   1.03903495  1.05023888  1.05804439  1.06250648
#   1.06368014  1.06162039  1.05638222  1.04802063  1.03659062  1.02214719
#   1.00474534  0.98551967  0.9604187   0.93300947  0.9003412   0.86588589
#   0.82967291  0.78879816  0.74179663  0.69793807  0.65162656  0.60222622
#   0.54939178  0.49460667  0.43883286  0.37837777  0.31959701  0.25623544
#   0.19616266  0.13286929  0.07140815  0.0107565  -0.05187674 -0.11289882
#  -0.17130659 -0.22938205 -0.28432964 -0.34007904 -0.39055734 -0.44241464
#  -0.49252051 -0.54266477 -0.59078182 -0.62941558 -0.6677962  -0.70369853
#  -0.7362117  -0.76659052 -0.79370439 -0.81368808 -0.83283632 -0.84901322
#  -0.86215196 -0.87218575 -0.87904778 -0.88267126 -0.88298937 -0.87993533
#  -0.87344232 -0.86344354 -0.8498722  -0.83266149 -0.8117446  -0.78705474
#  -0.7585251  -0.72608888 -0.68967929 -0.6492295  -0.60467273 -0.55594218
#  -0.50297103 -0.44569249 -0.38403975 -0.31794602 -0.24734449 -0.17216836
#  -0.09235083 -0.00782508  0.08147567  0.17561823]
